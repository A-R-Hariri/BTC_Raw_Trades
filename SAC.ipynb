# %%
from dataset import *
from train import *

# %%
seed_all(SEED)
if MODE == "prepare":
    prepare_dataset()
elif MODE == "train":
    train()
# Out:
# actor params: 2,035,716
# critic params: 2,282,440
# ep 0:   0%|          | 0/86400 [00:00<?, ?it/s]
